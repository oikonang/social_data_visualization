# %% [markdown]
# # Part 1: KNN
#
# > * *How does K-nearest-neighbors work? Explain in your own words.*
#
# K-nearest neighbors are a model of prediction that allows to predict values of variables according to the values of the neighbors.
#
# > * *Explain in your own words: What is the curse of dimensionality?*
#
# Curse of dimensionality is the trade-off data scientists have to deal with while applying K-nearest neighbors model to high dimensional datasets. It's a matter of truth that with high dimensional spaces distances between points get much more sparse, hence making it difficult to apply KNN. The lower the dimensions, the better the results. Otherwise, in order to apply KNN a dimensionality reduction might be applied before.
#
# > *Exercise: K-nearest-neighbors map.*
#
# >*The goal of this exercise is to create a useful real-world version of the example on pp153 in DSFS. We know from last week's exercises that the focus crimes PROSTITUTION, DRUG/NARCOTIC and DRIVING UNDER THE INFLUENCE tend to be concentrated in certain neighborhoods, so we focus on those crime types since they will make the most sense a KNN - map.*
# * *Begin by using geoplotlib to plot all incidents of the three crime types on their own map using `geoplotlib.kde()`. This will give you an idea of how the varioius crimes are distributed across the city.*

# %% [markdown]
# Let's start by copying some content from Week 3 notebook:

# %%
import requests
from matplotlib import pyplot as plt
import numpy as np
import csv
import pandas as pd
from pandas import DataFrame
# %matplotlib inline
import geoplotlib
from geoplotlib.utils import BoundingBox
from geoplotlib.colors import ColorMap
import sklearn
from sklearn import neighbors, datasets
from sklearn.neighbors import KNeighborsClassifier

# %%
#Storing the dataset as a dictionary (might be useful later on)
with open('..\data\sfpd_incidents.csv','rb') as f:
    reader = csv.DictReader(f)
    data_dict = [line for line in reader]
    
#Storing the dataset as a Pandas DataFrame
#Easily create DataFrame from list of dictionaries
data_dataframe = DataFrame(data_dict)
del data_dict
data_dataframe.head()
# Out:
#                        Address         Category        Date DayOfWeek  \
# 0        18TH ST / VALENCIA ST     NON-CRIMINAL  01/19/2015    Monday
# 1  300 Block of LEAVENWORTH ST          ROBBERY  02/01/2015    Sunday
# 2  300 Block of LEAVENWORTH ST          ASSAULT  02/01/2015    Sunday
# 3  300 Block of LEAVENWORTH ST  SECONDARY CODES  02/01/2015    Sunday
# 4       LOMBARD ST / LAGUNA ST        VANDALISM  01/27/2015   Tuesday
#
#                                     Descript IncidntNum  \
# 0                              LOST PROPERTY  150060275
# 1                      ROBBERY, BODILY FORCE  150098210
# 2       AGGRAVATED ASSAULT WITH BODILY FORCE  150098210
# 3                          DOMESTIC VIOLENCE  150098210
# 4  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES  150098226
#
#                                 Location  PdDistrict            PdId  \
# 0   (37.7617007179518, -122.42158168137)     MISSION  15006027571000
# 1  (37.7841907151119, -122.414406029855)  TENDERLOIN  15009821003074
# 2  (37.7841907151119, -122.414406029855)  TENDERLOIN  15009821004014
# 3  (37.7841907151119, -122.414406029855)  TENDERLOIN  15009821015200
# 4  (37.8004687042875, -122.431118543788)    NORTHERN  15009822628160
#
#   Resolution   Time                  X                 Y
# 0       NONE  14:00   -122.42158168137  37.7617007179518
# 1       NONE  15:45  -122.414406029855  37.7841907151119
# 2       NONE  15:45  -122.414406029855  37.7841907151119
# 3       NONE  15:45  -122.414406029855  37.7841907151119
# 4       NONE  19:00  -122.431118543788  37.8004687042875

# %% [markdown]
# Now that we imported the dataset in a Pandas dataframe, we can proceed with the exercise:

# %%
#Create a subset of the main dataframe with only the KNN crimes
knn_crimes = ['PROSTITUTION', 'DRUG/NARCOTIC', 'DRIVING UNDER THE INFLUENCE']
knn_data = data_dataframe[data_dataframe['Category'].isin(knn_crimes)]

def kde_plot(lats,longs):
    #Getting the coordinates for plotting (filter the outliers with Y=90)
    geo_data_for_plotting = {"lat": lats,
                             "lon": longs}
    #Ready for plotting
    print(crime+': KDE Map')
    geoplotlib.kde(geo_data_for_plotting,bw=3)
    bbox = BoundingBox(north=max(lats),
                       west=min(longs),
                       south=min(lats),
                       east=max(longs))
    geoplotlib.set_bbox(bbox)
    geoplotlib.inline()

for crime in knn_crimes:
    lats = [float(el) for el in list(knn_data[(knn_data['Y']!='90')&(knn_data['Category']==crime)]['Y'])]
    longs = [float(el) for el in list(knn_data[(knn_data['Y']!='90')&(knn_data['Category']==crime)]['X'])]
    kde_plot(lats,longs)
# Out:
# PROSTITUTION: KDE Map
# ('smallest non-zero count', 1.9901719039787654e-09)
# ('max count:', 21.749158532433501)
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%2BZ7niX1832JH%0AYCUAgkyuuTHXV6%2BqX1e9VmtGammmrWWS2ajnKl00d9101k0HnWWmMcl0aBtdJGv1zMhGo25Vd81U%0Av3r1Xq6PySW5gNgRCMTuu7sOHuGIQATAJckkmfx/zJgJRHh4eARicf/69/f9Sn//zXcpAoFAIBC8%0Ao0RhgCbBrVu3Ji7/8fFDGodNDMt%2BTVsmEAgEAoFAIBin0%2BuRhgEffnADx7KwLCe7vNtie2sXRZFZ%0AXFrkmx/ucNBocvHCBRRFfeXbFccRURhy9b1L%2BK5LoejQOm4jyzKqqmI7Fp12l7m5Gr4f0Ol0KFfK%0APH70GNM0uXbt%2Brnrd90%2Bt2//gKKqzNVqlMpFBq5Hpzug73qv/PEJBIKfhuv7bO5s88HV97hycX3i%0AOvk1bZNAIBAIBG8EiiLhetM7tKqqv4atEQgEAoFAIBCcRalQwDGNCVEWoFSscPPmTWzb5qhxxK2b%0A11E1lYOjo1e6PXEccdA84v7mJrVamTgM0XWdQd/Ftm1K5SJBEEzcxjB0SqUSjx49JknSZxJlv/32%0AO1RV5cLKCsVSkR8f77B70BSirEDwFhBFMdt7u6wuLU2JsiCEWYFAIBC840iyRhRFU5fbhkYaT18u%0AEAgEAoFAIHi9hFGI6/Zx3f7E5XNzNbq9Hpqq8cWHH9Dp9zlovhpx9uCowf3NTeIo4rP332dteZkk%0ASUiShCAIcBwbTdVQVZUgjEiSJL/tYDBg0Hf55JNPzr0P1%2B3z1VffUiyW2Lh0kWanze27P76SxyMQ%0ACF4NT/Z2KBcdPv/w5szrhTArEAgEAsEMdMMgSUTaj0AgEAgEAsGbQhxHlMslSsVK7pi9fft2LtBa%0AloOu6fT7A2qVMr/%2B5Ba9Xo/N3W3il3jCffdgn16/zxcffcg/%2BvNfsbayCIDtWHieh67rhFFIGIXo%0ApoE3nM7y/YC%2B6/Lw4WM%2B%2BeSjc%2B%2Bj1Trmq6%2B%2BpVIps3Jhme29BvuNIwzTemmPQyAQvFq29nZRZJk/%0A%2B%2BTWmcsIYVYgEAgE7zySJBOGk2Nmpm6SpkKYFQgEAoFAIHhTiMIQ2z7J/%2B%2B7LlEU0e8P8suq1Qq9%0AXibULtZr/NWvvkBTVB5vb%2BP2ez95Gw6OGriex1/96gsuLM5PXKepGkmSEgQBnXaX1nGbQa9PFETo%0ApgHAvTv3uX7z2kQUw2kajUNu377D4uI8c3M1ev0B7Xabgl38ydsvEAh%2BHg6aTTzf59effoKuaWcu%0A9%2BpTsAUCgUAgeMORJIkgCNC0k1xZwzBI0%2BScWwkEAoFAIBAIfk6SOMY0zfx3b%2BDiODadTod6PRNJ%0Ay%2BUSh4cPWByKpo5j85svP%2BUP3/3A5sEBcIBlGpQLRcrF0jPft%2B%2B5bB8cICsKv/70Fo5j0%2B8PiJKY%0AJIpJkoQoipFlCdM0SZIEz/PRdQ1ZliFJefDgAcvLS9Rr9TPvZ2dnm8ePn7B2cRUAwzR4dO%2BBcMoK%0ABG8RnV6Po%2BMmv/n0FqXC%2BWXSQpgVCAQCwTuPLGcFYI5TeN2bIhAIBAKBQCA4A02WcJwTkWMwGFCp%0AVNjZ2c0vsywHRZHp9wf5spqq8WeffEQYhTSP2xweHbO5u8teo0G1VKJWKqFqZxe/HjSPOG63ubA4%0Az62b19FUjXa3izfwkGUJVVVRdQ3HsTBNi263x8OHj6lUygwGmXs3jhNKpRIbGxtn3s9IlL169T0G%0AgwHz83X%2B/VffPpeALBAIXi%2Bu77N7eMCtm9eZnz/7JMwIIcwKBAKB4J1HUlT8KJi6XFVV0iREks8e%0APREIBAKBQCAQvHriOELTtIkIgMHAZW1tFdu2aLWOqVSqAFxYvcDjR4/ZuHQRTT3Zj9NUjcX5Oovz%0AdT68cZUnu7s8fLLDvc1NHNuiYDmoqoqhKgD0PZ9Wp525ZG99xOKYyKLKCrZtEUURURSRBCGBLNFu%0A99jd3ePajWvMVWvP/PharWMePnzMhx%2B9T7vVplQqsd9oMnBdIcwKBG8JURSwtbvDxQvLXF5bfabb%0ACGFWIBAIBAIg8sKpy3RdI0pkNJHILhAIBAKBQPBaicKQUulkusl1%2B6h6JrqWSiUODg5yYbZcqlCr%0Addne2mVurkaxOHsqam15mbXlZdrdLo82t2l2OhweN0mSLM7qf/ef/W/QVBVNVUHKbpOmWaRCMoy8%0AkiQZSZKQJEiTlCRJkCQJTT/bgTvOt/fu4bp9vvvue25%2B8D7dXg/btjEMnUe3t1EU5YWeL4FA8PMS%0ARTGPd3epV8p8cvPGM99OCLMCgUAgeOeRZZkwmiXM6nhhDIgdYoFAIBAIBILXiXe6%2BKs/wB7mzZbL%0AJY6PW%2Bzt7bK0tAzA6uoaBwf7dDoddnZ2sW0Lu%2BBQLBSminjKxSK3PjgRUsIoRFM1/veWObFcHGWC%0ArCIraKqGJJ06e69AHEUTBbJJkpAmCYp6tvzy7bffsbFxkTgMkTmJa0gSUUQrELwt7DUOMDSdzz/%2B%0A8LluJ4RZgUAgELzzSLKM53lTl6uGDqH7GrZIIBAIBAKBQDCOlqZYzniMwQDdNPLfL6wu8%2BjhY8rl%0AUh53sLCwyMLCIpBFBXQ6HTYfPwGgWCxSKDgTmbX5fanTMVZJkpCmKbpuTF03gQSM6alhEKAbZ7tn%0Ab9%2B%2BTaFQoFAo0Ol0pjMpJen8%2BxMIBK%2Bd/aMGfhjw2y%2B/mDrx8zSEMCsQCASCdx5FkQiC6YxZSzNo%0AR91zyyAEAoFAIBAIBK%2BWOI7QNRV7TIjt9wcsLc3nv2uqxsLCAoeHDdbXnal1VCrVPOrAdfu02x0O%0ADg7QdZ2FxfmZYmxOCnEco80QXNI0IU1SUlIkSUZRVFAgSWKiMEJV1Wln7djj6nY73Lh5ndZxm3Kl%0AfGrdwjErELzpHLfbtDod/sHnn8480fM0hDArEAgEgnceSdbwg2lnrGqK0i%2BBQCAQCASC103f9ajY%0AxkTxl%2B/7mKY1sVwURSRJyldffUWh4FCpVHAce%2BJ2AJblYFkOS0vLbG094dHDx6ysrJwpqsRxjCIr%0AEwJrFIZ5nqw0dLUmxERhmP%2BOxJkRBmmaEIYR165dI/BDdF2fctpFcYQsi7IDgeBNpe8OOGgecevm%0ADerVygutQwizAoFAIBCQ7cifxlB10nj6coFAIBCccHh0hGmaFJ1J4aPd7ZAkKbal4/mhaBUXCAQv%0ATBAGOHY1/911%2B%2Bj6pIh5dNTENE0cx6Y2V6HT7tLr9Tk4OACygrBSuUipWJm43erqGsVSkc3HT0jT%0ABFVV0XUdVdVI4iy%2BIEnTCdF0lCOr6bNO4iskcUIYRZimOeP64WMKQjRVxTB0er0exVJxapnjTocL%0Ai/Mzbi0QCF43fuizs7/PlYtrbFxYfuH1CGFWIBAIBIIzsExTlC4IBALBObS7HRqtYwDmazXq1Vp%2B%0AXblYYuPCAgBHR8fc29pmqb7wWrbzp9BstXADlzCMKdj2xGMUCASvnnh4kny8%2BKvb7eWiZxiFtI7b%0A2LaN49j577quMzdXA%2Bbx/YBer8f21i4P/EeUSkWWl5dyJ225VOGjjyq4bh8A3w8mYq407UQ6SdOE%0AOInPjj5IIYwijHNyZaMwRJYkZCUroE2SZMote3ScfbZahjVrFQKB4DUSRTFbe3vUqzU%2BuHrlJ61L%0ACLMCgUAgEACSJOP7PoZxkl2maQZJEr/GrRIIBII3m9HobRCGHDabeL7P0vwiqpKN ...
# DRUG/NARCOTIC: KDE Map
# ('smallest non-zero count', 1.9901719039787654e-09)
# ('max count:', 71.481904923832047)
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%0AyD0TOwGQBEiC%2B723uvtOdfXoRaWaMck0bbJ6kGmxMT3qQf%2BA/hE9SS8q04PMWqbuHpnpYazVNdNd%0Ay63LywUkAWJN5J6RsUf4dlwPvkRERkRmAgSQAHk%2BRjAzfD3u4R7p8T3f8/2Jf/zTNzEazTnw05PH%0ArCwvUi1W%2BOHhAzbWVqgWK%2BfdLI1G8ytm2G1z48Y7rCyvTkz/j3/7t5Tri%2BfUKo1Go9FoNBqNCH3W%0A19dYX9%2BYmH541GB3e5t33rl24vqHhw2UUti2TbFUoD8YctBoE4ThK2z120cUhXi9HosLdW7fvn3m%0A9e7evcvh4SFupYphmK%2BwhRrNLwt53g3Q/HqpVSs0jtqsLNdQSrF/0DjvJmk0ml85wjDpe8HUdNPU%0AD5cajUaj0Wg050ls2uzt7U1NX1pYRAhJq9OZu24QBlSqFWr1GqZt8Xhzh%2B29hhZlj%2BENB3jdLu/e%0AvH5mUbbdafJ3f/efOWp3KNUXtSir0Twn%2Bo7RnBvL9UUOjx5w9/5DLm6ssb27f95N0mg0v3IMAWHo%0AT00vuC5KBQhpnUOrNBqNRqPRaDQASsXs7GxPuWYvXtrg8aOn1CqTIzD9IODewyfcf/KEG5cuUS6X%0AGXrTz3q/dqIoJOj3KRRc3v/wEwqF0pnW29x8yqNHj3FKZQqW/YpbqdH8MtHCrOZc2VhbYXt3n/ff%0Auc4ztctRq8VCrXbezdJoNL9WDJNg6E1NtmyLvhdg6nEmGo1Go9FoNOdG5po9LsxWK3UKhX0ODxss%0ALS0ShAE/Pd7iwZPHAGysrGJathZlZxAGPl6vy6VLl7h27dqZ1hkMevx47z7dbp%2BSjvvSaH4WWpjV%0AnCvVYoVOscdBs8HtGze5%2B9N9pCGolavn3TSNRvMrJZwxpM22bXqDacFWo9FoNBqNRvN6USpma%2BsZ%0AFy5cnJh%2B8eIFfrx3n6NOj/tPnqCiiIVaXRt/TmDQ62KKmI8/%2BYhqpX6mdQ4aB9z74T7CsihW9bnV%0AaH4uWpjVnDtRFGGZJivLNeAmPzx8QBCGLOueN41G85oxDMFwhmPWsW2UUufQIo1Go9FoNBrNOLFp%0As39wwMJCfWLIfaFQolatce/pJtVSmcV6/fwa%2BYaTFfhaqFf54IMPz7ze/fv32NnZ1QW%2BNJqXiL6T%0ANOfCQbPB4VETAKUUd26/C5CKs9e5%2B9N9PM/n4tr6%2BTVSo9H86hDSwvf7U9NNp3AOrdFoNBqNRqPR%0AzCJWMUdHzaks1LW1FZrNJrGp807nEXhDguGQGzfemYqEmMdg0OObb74jULGOLtBoXjI6LU/z2ml3%0AuxweNdlYW2F9ZRmA//SHP/HHb3/ADwIWFsoAdPvT4ohGo9G8apSKpqZZpkkc6aq9Go1Go9FoNG8C%0AsWnTbDanphcKJVZXVxAzirlqYNhpY4qYzz//5Myi7NbWM/7wh6/AtCiUyq%2B4hRrNrw/tmNW8VvYO%0ADzhsNqmWy2zv7gNQLZdxHJtWu8N/%2BsOf8mWVUrT7HarFyrzNaTQazSshCHysscqyxYKNUvE5tkij%0A0Wg0Go1GkyFVgB/GHBzss7y8MjHvwoWLHBwcMN3V/uslikKGnfZzFfgC%2BPrrr2l3ujjlso4u0Ghe%0AEfrO0rxWjtptpJR0%2B30c22GhVskLfdm2xXDg4RYcwiDiqNXSoqxGo3ntCCGJonBCmLVMa6aTVqPR%0AaDQajUbz%2BlHSAgmbm88olYpTkQbr6%2BtsbW3rSAOSAl9CKT766EPq9YUzrdNsHnH37g%2B6wJdG8xrQ%0AwqzmtbKxskq1nAx/aPc7%2BH6Qz6sWKxNCrGHopA2NRvP6MQyJ5/m4bjGfNi7SajQajUaj0WjeDIQU%0AHB42uHRpUpitVPSQ%2BygK8bpdFhZqz1Xg69GjR2xubuKUypj6GVijeeVoYVbzWslE2QzbtuYumzlp%0ANRqN5nXT9wKOewOE0J1FGo1Go9FoNG8SSlocHByytLQ44Zo97qD9tRF4Q/xBn5s3bzxXga%2B7d7/H%0A8wJd4EujeY1oYVZzbuiYAo1G8yYiDJPQG0xNN22bWAUIOb9DSaPRaDQajUbzegmFnOmatW0LT51T%0Ao86RYaeN41jc%2BeKzMwvUe3u73Lv/AMtxcCvaIKXRvE60MKvRaDQazTG8KJya5lomQRRjauOsRqPR%0AaDQazRuDYZgzXbOmaeL5v54aAVmBrwsXNrh%2B/caZ17t79y6NxpEu8KXRnBP6rtNoNBqNZgzDNAk9%0Af2q6ZVv4A%2B8cWqTRaDQajUajOY3%2B0JsSZuVwmBQK%2B4XjDQfEQfBcBb7anSbf3/2BMBYUa/VX20CN%0ARjMXLcxqNBqNRnMMbzgtwNq2Tac3HXGg0Wg0Go1GozlfhBQE3uTzm23/8gtXRVGI1%2BtRrZS58%2BUX%0AZ17vyZPHPHnyFKdUpqALfGk054oWZjUajUajGcMwBIEfTE13fgUP9xqNRqPRaDRvK74/OeLJNE2C%0AWGCcU3teNYNel57v8%2BGNd7hw4eLZ1hn0%2BPHeffq9AW6lqqMLNJo3AH0XajQajUYzhpAWntebmm46%0ABeIZ2bMajUaj0Wg0mvNFSYvhcDgxzTRNwiD4xYiPURTS7fcp2jaLtQr9dsRv7nx45vUPGgfc%2B%2BE%2B%0AwrJ0gS%2BN5g3il/EJpdFoNBrNSySOp0v4Fp1ffj6ZRqPRaDQazduKd6xGgGVbSPXL6FT3hgO2Dw/5%0A7Pb7SODZs20%2B/%2BzjPFN3MOhN5Ose5/79e2xu71KuapesRvOmoe9IjUaj0WhmEAQ%2B1ljmluPYKBWf%0AY4s0Go1Go9FoNPMIgklh1rYshJDn1JqXi2lZ/E///F/w7NkW%2B/uHfPrpnQkhdp4oOxj0%2BOab74hj%0AhacUNS3KajRvHPqu1Gg0Go3mGEJIgjCYEGYNw0Sp6BxbpdFoNBqNRqM5iVnO0SgK31iXaBj4RFHy%0AfFkuVygW3Hze0BvQ6w24enEDx3W4f/8Bg0F/SpSdx9bWMx4%2BesLG%2BirLK0s82zlgeMxVrNFozp83%0A89NJo9FoNJpzxDAknudRHHvotXTFWo1Go9FoNJo3liiajKLyPJ9AxXRaLVYXl86pVZO0u13iWFG0%0Aba5c3KBWG2W99ocecTQyASwvVrFMi1arzcMHjwiCgN/%2B9ndn2s/XX39NEPi8/95Nut3p2gkajebN%0AQQuzGo1Go9EcQxgmQ3/aHSvlL7Wur0aj0Wg0Gs3bjWHICSdpt9tleaHGkx/uUSsWcdzCubXNGw7o%0Aez6ff3gLx7HxPB/f99nd3c%2BXcV0H0zRRKhGYG4fN5GfjEIDf/OY3p%2B6n2Tzi7t0fWFlZ4ubN6xwe%0ANqjUqvR7A%2B2W1WjeULQwq9FoNBrNDEJvMDXNti1iFSCkLgSm0Wg0Go1G86YQBj7usdFNnU6X9fUV%0ALjabbB8ecu3ipXNp297hAVJKfvfpR3Q7PdrtNqZpYpqJHOO6Do5j4c4Qju/df8DiQp3bt2%2Bfup9H%0Ajx6xvb3DjRvv4BYcjo6amKZJHCu2D45e%2BnFpNJqXwy8jCVuj0Wg0mpeIlBLPn3YVuK5DFOkCYBqN%0ARqPRaDRvCq1Om2a3S6VSmZjueR6uW%2BDOe%2B%2BhoohGs/na29ZoNikWHH7/5We0O12klKysLLOwUKdS%0AKSOlwDRNgmBypFYQBvz44z1uXL92JlH2u%2B%2B%2BpdlscuPGO/i%2BT/OohW3b1GpVvv3xwas6PI1G ...
# DRIVING UNDER THE INFLUENCE: KDE Map
# ('smallest non-zero count', 3.0077073102663826e-08)
# ('max count:', 1.7514932450777021)
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...%2BBp7%0AZOSCTOwEQAIkCO5k9UxXV6G6p%2BfO3B7dkY2kqx7de2V6kR5k0rse9VfIZCbTo6TRYpLMpJk7czXd%0ARVZ39fRSC3dwAbEj94yMPXw9rgdfIiIjIjNBAgRAnk8VmBG%2BHvfw8Ij4nu/5/rTffvxpjELxPdLp%0A9aiWy8njQRffD1iqN2Yu2%2B51qJWr32fzFAqFArfX4eUrl6nV6hPT//rXv6Y8536lUCgUCoVCofj%2B%0AETJgsdHg9OkzE9OHwz5ffvk1sWE9pZY9faIoxOv1WFio8corV4%2B93p07d3jw4AF2qYxh/njPn0Lx%0AfWA87QYofnxkomyGZZlzl1WirEKheFoMvIDagWmaJp5KWxQKhUKhUCgUs5HCZHd3j8XFBoVCKZ8%2B%0A/vjHSOC5%2BMMBly5dZHV17VjrDId9btz4As8LKCkzgkLxvaCEWcVTpVqsPO0mKBQKxRSabhB6w6np%0AhmURywBNzO9QUigUCoVCoVB8v4SaYG%2BvyenTk2KsZZl48ik16inidjvYtsm1t988tkC9vb3F1zdv%0AYdo2TkUZpBSK7wslzCoUCoVCMQMvCqemOaZBEMUYyjirUCgUCoVC8cyg68ZM16xhGHh%2B9BRb9v0S%0ARSFut8PJk2tcuHDx2OvduHGDZnMfu1xG15VMpFB8n6h3nEKhUCgUB9ANg9Dzp6ablok/9J5CixQK%0AhUKhUCgURzFwvSlhVrgu8kcw2slzh8RBwKuvXqVeXzjWOp1uiy9ufEkYaxQP1FZQKBTfD0qYVSgU%0ACoViBp47LcBalkW3Px1xoFAoFAqFQqF4umhCI/Amv79Z1g%2B/cFUUhXj9PtVKmWvvvH3s9e7du8u9%0Ae/exS2UKqsCXQvHUUMKsQqFQKBQH0HWNwA%2Bmpts/gi/3CoVCoVAoFM8rvj854skwDIJYQ39K7XnS%0ADPs9%2Br7P1YsvcPLkqeOtM%2Bzz1dc3GfSHOJWqii5QKJ4y6h2oUCgUCsUBNGHief2p6YZdIJ6RPatQ%0AKBQKhUKheLpIYeK67sQ0wzAIg%2BAHIz5GUUhvMKBoWTRqFQadiHevXT32%2BrvNXb7%2B8iaaaaoCXwrF%0AM8IP4%2B6kUCgUCsVjJo6nS/gW7R9%2BPplCoVAoFArF84p3oEaAaZkI%2BcPoVPfcIRt7e7z58mUE8PDh%0ABm%2B9%2BVqeqTsc9ifydQ9y8%2BbXPNjYolxVLlmF4llCvRsVCoVCoZhDEPiYY5lbtm0hZfwUW6RQKBQK%0AhUKhmEcQTAqzlmmiaeIptebxYpgm/%2Bxnf8jDh%2Bvs7OzxxhvXJoTYeaLscNjn008/J44lnpTUlCir%0AUDxTqHekQqFQKBQz0DRBEAYTwqyuG0gZPcVWKRQKhUKhUCgOY5ZzNIrCZ9YlGgY%2BUZR8vyyXKxQL%0ATj7P9Yb0%2B0POnVrDdmxu3rzFcDiYEmXnsb7%2BkNt37rG2usLS8iIPN3dxD7iKFQrF0%2BXZvDMpFAqF%0AQvGU0XWB53kUx770mqpirUKhUCgUCsUzSxRNRlF5nk8gY7rtNiuNxafUqkk6vR5xLClaFmdPrVGr%0AjbJeB65HHI1MAEuNKqZh0m53uH3rDkEQ8N57PznWfj755BOCwOfyS5fo9aZrJygUimcDJcwqFAqF%0AQjEDTTdw/Wl3rBA/1Lq%2BCoVCoVAoFM83ui4mnKS9Xo%2BlhRr3vvyaWrGI7RSeWts8d8jA83nr6hVs%0A28LzfHzfZ2trJ1/GcWwMw0DKRGBu7rWSv809AN59990j99Nq7XPjxpcsLy9y6dIF9vaaVGpVBv2h%0AcssqFM8gSphVKBQKhWIOoTecmmZZJrEM0IQqBKZQKBQKhULxrBAGPs6B0U3dbo/V1WVOtVps7O1x%0A/tTpp9K27b1dhBD85I1X6XX7dDodDMPAMBJJxnFsbNvEmSEcf33zFo2FOi%2B//PKR%2B7lz5w4bG5tc%0AvPgCTsFmf7%2BFYRjEsWRjd/%2BxH5dCofju/DBSsBUKhUKheMwIIfD8aVeB49hEkSoAplAoFAqFQvGs%0A0O52aPV6VCqVieme5%2BE4Ba699BIyimi2Wt9725qtFsWCzU/feZNOt4cQguXlJRYW6lQqZYTQMAyD%0AIJgcqRWEAV999TUXL5w/lij7%2Beef0Wq1uHjxBXzfp7XfxrIsarUqn31160kdnkKh%2BI4oYVahUCgU%0AihloQuDPEGYzZ4NCoVAoFAqF4tlgv9PBBMrlUYzBcJjkqna7PWzb4tqVF9nZb%2BK50yOiniQylrxz%0A7VX29vcxhI5hGHhppEAQBgCYlonruvlzgC9ufMmlSxdZXV07ch8fffwRQRhSr9eRUlKpVqgv1HB9%0Aj9v3H1Atl5/MwSkUiu%2BMEmYVCoVCoZhD4AdT00zHJgrDp9AahUKhUCgUCsUsGrV68kBouSBbKJS4%0AcPE8e3tN7t9/wImlJU6dWObh9jZR9P18l4uikEqhwMD1EGgUSwUGgwG9Xo92u5M0WQgs06RardLa%0Ab%2BMHAV9/fZN6vX6kKDsc9vnd734LwGKjQWOxDkJja6fJN3fX2Wl28GbUTFAoFM8GQ89TwqxCoVAo%0AFLPQdY2h605NNwxrxtIKhUKhUCgUiqdFtVym5NiUCoWJ4l/VSpLNWiwW2dvd4/WXL2OYBtt7e0%2B0%0APVEUst3c4%2Ba9ezQaNaIgwLIsBv0hxWKRaq0yNTLLti2q1Sp37txFypiXXrp86D6Gwz6ffPIphmFw%0A6uRJKtUK39xdZ2O7SX84/R1WoVA8W4RhxMPNDSXMKhQKhUIxC02YhDOcsUXbJP6eXBYKhUKhUCgU%0AiuMThAHDYT93zWYsLjbo9nqYhsk7r16l0%2B%2Bz3Xwy4uz23i43790jCkPeeuUVzqytIaVESonv%2B5RK%0ARUzDxDAM/CBESpmvOxgMGPSHvPHGG4fuYzjs8%2BGHn1CpVDn/wjmanTY3vvrmiRyPQqF4MtzfXKdW%0AKSlhVqFQKBSKR8GybaRUxb8UCoVCoVAonhWiKKRWq1Kt1HPH7I0bNyZiDSzTot8f0KjX%2BIM3XqfX%0A63Fv4%2BFjjTXY2N6i1%2B/zzrVX%2BcU/eo8zJ08AUCwVcF0Xy7IIwoAgDLAcGzcdneV5Pv3hkNu37/LG%0AG9cO3Uertc%2BHH35CvV7j5Kk1Hm7usrW7h%2B0UHttxKBSKJ8uDzQ10IfjJG68rYVahUCgUinlomiAI%0AJoeZOZZDHCthVqFQKBQKheJZIQwCisVi/rw/HBKGIf3%2BIJ%2B2sFCn10uE2hNLDX7%2B3juYusHdhw8Z%0A9nvfuQ3be7sMXZefv/cOp04sT8wzDRMpY3zfp9Pu0tpvM%2Bj1Cf0Qy7EB%2BPrLm1x%2B%2BaWJKIaD7O7u%0AcOPGl5w4scziYoNef0C73aZcrHzn9isUiu%2BH7WYT1/P4gzffwDJNVGlphUKhUCjmoGkavu9jmqNc%0AWdu2iWN5yFoKhUKhUCgUiu8TGUU4jpM/dwdDSqUinU6HpaVEJK3Vquzs3OJEKpqWSkV%2B%2Bu6b/O7T%0AL7i3vQ1sU3BsauUKtUr12Pv23CEPt7cRus4fvPk6pVKRfn9AKCNkGCGlJAwjhNBwHAcpJa7rYVkm%0AQgiQMbdu3WJtbZWlxtLc/ayvP%2BTu3fucOXcaANuxufP1LeWUVSieIzq9Hnv7TX765utUy0lnkhJm%0AFQqFQqGYgxBJAbBSqfy0m6JQKBQKhUKhmIMpNEqlkWN2MBhQr9dZX9/IpxUKJXRd0O ...

# %% [markdown]
# > *Next, it's time to set up your model based on the actual data.*
#
# > * *You don't have to think a lot about testing/trainig and accuracy for this exercise. We're mostly interested in creating a map that's not too problematic. But do calculate the number of observations of each crime-type respectively. You'll find that the levels of each crime varies (lots of drug arrests, an intermediate amount of prostitiution registered, and very little drunk driving in the dataset). Since the algorithm classifies each point according to it's neighbors, what could a consequence of this imbalance in the number of examples from each class mean for your map?*

# %%
print 'Total number of observations:',len(knn_data.index)

for crime in knn_crimes:
    print 'Total number of ',crime,'observations:',len(knn_data[knn_data['Category']==crime].index)
# Out:
# Total number of observations: 136596
# Total number of  PROSTITUTION observations: 16163
# Total number of  DRUG/NARCOTIC observations: 115131
# Total number of  DRIVING UNDER THE INFLUENCE observations: 5302

# %% [markdown]
# > * *You can make the dataset 'balanced' by grabbing an equal number of examples from each crime category. How do you expect that will change the KNN result? In which situations is the balanced map useful - and when is the map that data in proportion to occurrences useful? Choose which map you will work on in the following.*

# %% [markdown]
# > * *Now create an approximately square grid of point that runs over SF. You get to decide the grid-size, but I recommend somewhere between 50×50 and 100×100 points. I recommend plotting using geoplotlib.dot().*

# %%
geoplotlib.dot([float(el) for el in list(knn_data[(knn_data['Y']!='90')&(knn_data['Category']=='DRIVING UNDER THE INFLUENCE')]['Y'])])
geoplotlib.inline()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ricky\Anaconda2\lib\site-packages\geoplotlib\__init__.py", line 32, in _runapp
#     app.start()
#   File "C:\Users\ricky\Anaconda2\lib\site-packages\geoplotlib\core.py", line 364, in start
#     self.proj.fit(BoundingBox.from_bboxes([l.bbox() for l in self.geoplotlib_config.layers]),
#   File "C:\Users\ricky\Anaconda2\lib\site-packages\geoplotlib\layers.py", line 159, in bbox
#     return BoundingBox.from_points(lons=self.data['lon'], lats=self.data['lat'])
# TypeError: list indices must be integers, not str
